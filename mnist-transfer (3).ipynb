# %%
from __future__ import print_function
import imageio, keras
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile
from IPython.display import display, Image
from sklearn.linear_model import LogisticRegression
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle

import tensorflow as tf
from keras import backend as K

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"
#This will make it so that only the 0th GPU is visible to TensorFlow.
#In your case, you can choose any in the range [0, 3].
#If you wanted, for example, the 0th and 2nd GPUs to both be visible, replace "0" with "0,2"
GPU=True
CPU=False
num_cores = 4

if GPU:
    num_GPU = 1
    num_CPU = 1
if CPU:
    num_CPU = 1
    num_GPU = 0

config = tf.ConfigProto(intra_op_parallelism_threads=num_cores,\
        inter_op_parallelism_threads=num_cores, allow_soft_placement=True,\
        device_count = {'CPU' : num_CPU, 'GPU' : num_GPU},\
#        gpu_options=tf.GPUOptions(per_process_gpu_memory_fraction=0.5))
                       )
session = tf.Session(config=config)
K.set_session(session)
# %matplotlib inline
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-4-dda83db6177a> in <module>
#      14     num_GPU = 0
#      15
# ---> 16 config = tf.ConfigProto(intra_op_parallelism_threads=num_cores,\
#      17         inter_op_parallelism_threads=num_cores, allow_soft_placement=True,\
#      18         device_count = {'CPU' : num_CPU, 'GPU' : num_GPU},\
#
# AttributeError: module 'tensorflow' has no attribute 'ConfigProto'

# %%
from keras.datasets import mnist

num_classes=10

img_rows, img_cols = 28, 28
(x_train, y_train), (x_test, y_test) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('train_dataset shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train_onehot = keras.utils.to_categorical(y_train, num_classes)
y_test_onehot = keras.utils.to_categorical(y_test, num_classes)
# Out:
# train_dataset shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
# Copy data to 3 channels and resample to get 56x56 images
# VGG needs atleast 48x48, so resample
# Center and resample diffraction array to desired pixel spacing
from scipy.ndimage.interpolation import zoom

def resample(diff3D, Nx, Ny): 
    nx, ny, nz = diff3D.shape
    diff3D=zoom(diff3D, (float(Nx)/nx,float(Ny)/ny, 1), order=1)
    return diff3D


from tqdm import tqdm
def copy3channels(input_data):
    dims = input_data.shape
    dataset3 = np.zeros((dims[0],28,28,3),float)
    for i in tqdm(range(dims[0])):
        dataset3[i,:,:,0], dataset3[i,:,:,1], dataset3[i,:,:,2] = input_data[i,:,:,0], input_data[i,:,:,0], input_data[i,:,:,0]
    data=[]
    for i in tqdm(range(dims[0])):
        tmp=resample(dataset3[i,:,:,:],56,56)
        data.append(tmp)
    return np.array(data)

# %%
x_train_prepro = copy3channels(x_train)
x_test_prepro = copy3channels(x_test)
# Out:
# 100%|██████████| 60000/60000 [00:01<00:00, 45807.71it/s]
# 100%|██████████| 60000/60000 [00:54<00:00, 1108.33it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 104865.73it/s]
# 100%|██████████| 10000/10000 [00:08<00:00, 1249.94it/s]

# %%
K.clear_session()

from keras.layers import Conv2D, MaxPool2D
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras import backend as K
from keras.utils import to_categorical

import keras
from keras.applications.vgg16 import VGG16
from keras.optimizers import SGD
from keras.models import Model, load_model
from keras.layers import GlobalMaxPooling2D
from keras.utils import np_utils
from keras import regularizers
weight_decay = 0.0005

#base_model.layers.pop() 
#Pop out the current logistic layer
base_model = VGG16(input_shape=(56, 56, 3), weights='imagenet', include_top=False)

tmp = Flatten()(base_model.output)
#Add a fully connected layer
tmp = Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(weight_decay), name='fc1')(tmp)
tmp = BatchNormalization()(tmp)
tmp = Dropout(0.5)(tmp)
tmp = Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(weight_decay), name='fc2')(tmp)
tmp = BatchNormalization()(tmp)
tmp = Dropout(0.5)(tmp)
predictions = Dense(10, activation='softmax')(tmp)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

#Fix the first 15 layers
for layer in model.layers[:15]:
    layer.trainable = False 
    
sgd = SGD(lr=1e-3, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

#Save model every epoch
# checkpoints=keras.callbacks.ModelCheckpoint('vgg_weights/weights.{epoch:02d}.hdf5', monitor='val_loss', 
                                # verbose=0, save_best_only=False, save_weights_only=False, mode='auto', period=1)

# print (model.summary())


# history=model.fit(x_train_prepro, y_train_onehot,
                #np_utils.to_categorical(labels,n_labels),  
                # batch_size=batch_size, epochs=epochs, verbose=1, validation_split = 0.25, callbacks=[checkpoints])

# %%
## Callback for loss logging per epoch
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
batch_size=128
epochs=30

class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.val_losses = []
        self.accuracy = []
        self.val_accuracy = []
        
    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))
        self.accuracy.append(logs.get('accuracy'))
        self.val_accuracy.append(logs.get('val_accuracy'))

early_stopping = EarlyStopping(monitor='val_loss', patience=100, verbose=1, mode='auto')

def run_vgg16():
    
    history = LossHistory()
    model.fit(x_train_prepro, y_train_onehot, batch_size=batch_size, epochs=epochs,
              validation_split=0.25, verbose=1, shuffle=True, callbacks=[history, early_stopping])
    

    predictions = model.predict(x_test_prepro, verbose=0)
    return predictions, history

def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
predictions, history = run_vgg16()
print(model.summary())
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/30
# 45000/45000 [==============================] - 28s 633us/step - loss: 2.5669 - accuracy: 0.9762 - val_loss: 2.5496 - val_accuracy: 0.9781
# Epoch 2/30
# 45000/45000 [==============================] - 28s 621us/step - loss: 2.5173 - accuracy: 0.9866 - val_loss: 2.5146 - val_accuracy: 0.9857
# Epoch 3/30
# 45000/45000 [==============================] - 28s 622us/step - loss: 2.4902 - accuracy: 0.9898 - val_loss: 2.5297 - val_accuracy: 0.9770
# Epoch 4/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 2.4664 - accuracy: 0.9917 - val_loss: 2.4649 - val_accuracy: 0.9909
# Epoch 5/30
# 45000/45000 [==============================] - 28s 621us/step - loss: 2.4441 - accuracy: 0.9931 - val_loss: 2.4589 - val_accuracy: 0.9876
# Epoch 6/30
# 45000/45000 [==============================] - 28s 621us/step - loss: 2.4243 - accuracy: 0.9936 - val_loss: 2.4282 - val_accuracy: 0.9920
# Epoch 7/30
# 45000/45000 [==============================] - 28s 620us/step - loss: 2.4043 - accuracy: 0.9950 - val_loss: 2.4147 - val_accuracy: 0.9905
# Epoch 8/30
# 45000/45000 [==============================] - 28s 621us/step - loss: 2.3864 - accuracy: 0.9954 - val_loss: 2.4196 - val_accuracy: 0.9854
# Epoch 9/30
# 45000/45000 [==============================] - 28s 620us/step - loss: 2.3686 - accuracy: 0.9959 - val_loss: 2.3935 - val_accuracy: 0.9883
# Epoch 10/30
# 45000/45000 [==============================] - 28s 618us/step - loss: 2.3486 - accuracy: 0.9966 - val_loss: 2.3694 - val_accuracy: 0.9920
# Epoch 11/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 2.3312 - accuracy: 0.9970 - val_loss: 2.3486 - val_accuracy: 0.9925
# Epoch 12/30
# 45000/45000 [==============================] - 28s 620us/step - loss: 2.3142 - accuracy: 0.9972 - val_loss: 2.3518 - val_accuracy: 0.9880
# Epoch 13/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 2.2974 - accuracy: 0.9976 - val_loss: 2.3263 - val_accuracy: 0.9893
# Epoch 14/30
# 45000/45000 [==============================] - 28s 622us/step - loss: 2.2808 - accuracy: 0.9978 - val_loss: 2.3081 - val_accuracy: 0.9901
# Epoch 15/30
# 45000/45000 [==============================] - 28s 622us/step - loss: 2.2648 - accuracy: 0.9977 - val_loss: 2.2901 - val_accuracy: 0.9917
# Epoch 16/30
# 45000/45000 [==============================] - 28s 618us/step - loss: 2.2480 - accuracy: 0.9982 - val_loss: 2.2725 - val_accuracy: 0.9913
# Epoch 17/30
# 45000/45000 [==============================] - 28s 622us/step - loss: 2.2324 - accuracy: 0.9984 - val_loss: 2.2502 - val_accuracy: 0.9933
# Epoch 18/30
# 45000/45000 [==============================] - 28s 621us/step - loss: 2.2156 - accuracy: 0.9987 - val_loss: 2.2399 - val_accuracy: 0.9929
# Epoch 19/30
# 45000/45000 [==============================] - 28s 624us/step - loss: 2.1992 - accuracy: 0.9990 - val_loss: 2.2276 - val_accuracy: 0.9918
# Epoch 20/30
# 45000/45000 [==============================] - 28s 619us/step - loss: 2.1852 - accuracy: 0.9986 - val_loss: 2.2132 - val_accuracy: 0.9912
# Epoch 21/30
# 45000/45000 [==============================] - 28s 621us/step - loss: 2.1697 - accuracy: 0.9987 - val_loss: 2.1990 - val_accuracy: 0.9911
# Epoch 22/30
# 45000/45000 [==============================] - 28s 620us/step - loss: 2.1544 - accuracy: 0.9988 - val_loss: 2.1822 - val_accuracy: 0.9918
# Epoch 23/30
# 45000/45000 [==============================] - 28s 620us/step - loss: 2.1383 - accuracy: 0.9990 - val_loss: 2.1640 - val_accuracy: 0.9928
# Epoch 24/30
# 45000/45000 [==============================] - 28s 622us/step - loss: 2.1235 - accuracy: 0.9990 - val_loss: 2.1557 - val_accuracy: 0.9907
# Epoch 25/30
# 45000/45000 [==============================] - 28s 621us/step - loss: 2.1079 - accuracy: 0.9993 - val_loss: 2.1333 - val_accuracy: 0.9930
# Epoch 26/30
# 45000/45000 [==============================] - 28s 618us/step - loss: 2.0938 - accuracy: 0.9991 - val_loss: 2.1195 - val_accuracy: 0.9939
# Epoch 27/30
# 45000/45000 [==============================] - 28s 623us/step - loss: 2.0789 - accuracy: 0.9992 - val_loss: 2.1051 - val_accuracy: 0.9935
# Epoch 28/30
# 45000/45000 [==============================] - 28s 621us/step - loss: 2.0649 - accuracy: 0.9991 - val_loss: 2.0964 - val_accuracy: 0.9920
# Epoch 29/30
# 45000/45000 [==============================] - 28s 622us/step - loss: 2.0496 - accuracy: 0.9995 - val_loss: 2.0751 - val_accuracy: 0.9935
# Epoch 30/30
# 45000/45000 [==============================] - 28s 621us/step - loss: 2.0352 - accuracy: 0.9996 - val_loss: 2.0586 - val_accuracy: 0.9942
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 56, 56, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 56, 56, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 56, 56, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 28, 28, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 28, 28, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 28, 28, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 14, 14, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 14, 14, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 14, 14, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 14, 14, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 7, 7, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 7, 7, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 7, 7, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 7, 7, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              2101248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4096)              16384
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4096)              16384
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 33,670,986
# Trainable params: 26,019,338
# Non-trainable params: 7,651,648
# _________________________________________________________________
# None

# %%
fig1 = plt.figure(figsize = (12,10))
ax1 = fig1.add_subplot(2,2,1)
ax2 = fig1.add_subplot(2,2,2)

ax1.plot(np.arange(1,epochs+1), history.val_losses)
ax1.set(xlabel='Epochs', ylabel='Validation Loss',
       title='Epochs vs. Validation Loss')
ax2.plot(np.arange(1,epochs+1), history.losses)
ax2.set(xlabel='Epochs', ylabel='Training Loss',
       title='Epochs vs. Training Loss')
plt.show()

# %%
fig1 = plt.figure(figsize = (12,10))
ax1 = fig1.add_subplot(2,2,1)
ax2 = fig1.add_subplot(2,2,2)

ax1.plot(np.arange(1,epochs+1), history.val_accuracy)
ax1.set(xlabel='Epochs', ylabel='Validation Accuracy',
       title='Epochs vs. Validation Accuracy')
ax2.plot(np.arange(1,epochs+1), history.accuracy)
ax2.set(xlabel='Epochs', ylabel='Training Accuracy',
       title='Epochs vs. Training Accuracy')
plt.show()

# %%
epochs = 30
predictions1, history1 = run_vgg16()
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 2.0213 - accuracy: 0.9994 - val_loss: 2.0479 - val_accuracy: 0.9936
# Epoch 2/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 2.0064 - accuracy: 0.9997 - val_loss: 2.0308 - val_accuracy: 0.9936
# Epoch 3/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 1.9926 - accuracy: 0.9997 - val_loss: 2.0204 - val_accuracy: 0.9935
# Epoch 4/30
# 45000/45000 [==============================] - 28s 613us/step - loss: 1.9787 - accuracy: 0.9997 - val_loss: 2.0040 - val_accuracy: 0.9939
# Epoch 5/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 1.9650 - accuracy: 0.9997 - val_loss: 1.9903 - val_accuracy: 0.9941
# Epoch 6/30
# 45000/45000 [==============================] - 28s 613us/step - loss: 1.9512 - accuracy: 0.9998 - val_loss: 1.9766 - val_accuracy: 0.9935
# Epoch 7/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 1.9385 - accuracy: 0.9995 - val_loss: 1.9628 - val_accuracy: 0.9941
# Epoch 8/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 1.9249 - accuracy: 0.9995 - val_loss: 1.9517 - val_accuracy: 0.9942
# Epoch 9/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 1.9120 - accuracy: 0.9995 - val_loss: 1.9371 - val_accuracy: 0.9940
# Epoch 10/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 1.8980 - accuracy: 0.9997 - val_loss: 1.9296 - val_accuracy: 0.9927
# Epoch 11/30
# 45000/45000 [==============================] - 28s 617us/step - loss: 1.8855 - accuracy: 0.9995 - val_loss: 1.9133 - val_accuracy: 0.9941
# Epoch 12/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 1.8717 - accuracy: 0.9997 - val_loss: 1.9004 - val_accuracy: 0.9937
# Epoch 13/30
# 45000/45000 [==============================] - 28s 612us/step - loss: 1.8586 - accuracy: 0.9999 - val_loss: 1.8825 - val_accuracy: 0.9943
# Epoch 14/30
# 45000/45000 [==============================] - 28s 617us/step - loss: 1.8463 - accuracy: 0.9996 - val_loss: 1.8696 - val_accuracy: 0.9943
# Epoch 15/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 1.8332 - accuracy: 0.9997 - val_loss: 1.8609 - val_accuracy: 0.9931
# Epoch 16/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 1.8210 - accuracy: 0.9996 - val_loss: 1.8498 - val_accuracy: 0.9938
# Epoch 17/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 1.8077 - accuracy: 0.9999 - val_loss: 1.8360 - val_accuracy: 0.9937
# Epoch 18/30
# 45000/45000 [==============================] - 28s 617us/step - loss: 1.7954 - accuracy: 0.9998 - val_loss: 1.8246 - val_accuracy: 0.9937
# Epoch 19/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 1.7828 - accuracy: 0.9999 - val_loss: 1.8135 - val_accuracy: 0.9944
# Epoch 20/30
# 45000/45000 [==============================] - 28s 612us/step - loss: 1.7707 - accuracy: 0.9998 - val_loss: 1.8058 - val_accuracy: 0.9926
# Epoch 21/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 1.7586 - accuracy: 0.9999 - val_loss: 1.7879 - val_accuracy: 0.9937
# Epoch 22/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 1.7465 - accuracy: 0.9998 - val_loss: 1.7778 - val_accuracy: 0.9935
# Epoch 23/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 1.7342 - accuracy: 0.9998 - val_loss: 1.7647 - val_accuracy: 0.9934
# Epoch 24/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 1.7224 - accuracy: 0.9998 - val_loss: 1.7519 - val_accuracy: 0.9941
# Epoch 25/30
# 45000/45000 [==============================] - 28s 617us/step - loss: 1.7103 - accuracy: 0.9998 - val_loss: 1.7433 - val_accuracy: 0.9937
# Epoch 26/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 1.6989 - accuracy: 0.9998 - val_loss: 1.7335 - val_accuracy: 0.9930
# Epoch 27/30
# 45000/45000 [==============================] - 28s 617us/step - loss: 1.6874 - accuracy: 0.9998 - val_loss: 1.7156 - val_accuracy: 0.9939
# Epoch 28/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 1.6753 - accuracy: 0.9999 - val_loss: 1.7072 - val_accuracy: 0.9937
# Epoch 29/30
# 45000/45000 [==============================] - 27s 611us/step - loss: 1.6636 - accuracy: 0.9999 - val_loss: 1.6988 - val_accuracy: 0.9935
# Epoch 30/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 1.6522 - accuracy: 0.9999 - val_loss: 1.6815 - val_accuracy: 0.9938

# %%
sgd = SGD(lr=1e-2, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
epochs = 30
predictions2, history2 = run_vgg16()
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/30
# 45000/45000 [==============================] - 29s 642us/step - loss: 1.6767 - accuracy: 0.9798 - val_loss: 1.8725 - val_accuracy: 0.9393
# Epoch 2/30
# 45000/45000 [==============================] - 28s 623us/step - loss: 1.5401 - accuracy: 0.9885 - val_loss: 1.5397 - val_accuracy: 0.9808
# Epoch 3/30
# 45000/45000 [==============================] - 28s 623us/step - loss: 1.4347 - accuracy: 0.9907 - val_loss: 1.4079 - val_accuracy: 0.9866
# Epoch 4/30
# 45000/45000 [==============================] - 28s 623us/step - loss: 1.3348 - accuracy: 0.9919 - val_loss: 1.3820 - val_accuracy: 0.9687
# Epoch 5/30
# 45000/45000 [==============================] - 28s 624us/step - loss: 1.2409 - accuracy: 0.9933 - val_loss: 1.2239 - val_accuracy: 0.9900
# Epoch 6/30
# 45000/45000 [==============================] - 28s 625us/step - loss: 1.1589 - accuracy: 0.9940 - val_loss: 1.1393 - val_accuracy: 0.9916
# Epoch 7/30
# 45000/45000 [==============================] - 28s 625us/step - loss: 1.0809 - accuracy: 0.9946 - val_loss: 1.0862 - val_accuracy: 0.9872
# Epoch 8/30
# 45000/45000 [==============================] - 28s 625us/step - loss: 1.0080 - accuracy: 0.9950 - val_loss: 1.0206 - val_accuracy: 0.9845
# Epoch 9/30
# 45000/45000 [==============================] - 28s 626us/step - loss: 0.9370 - accuracy: 0.9959 - val_loss: 0.9383 - val_accuracy: 0.9913
# Epoch 10/30
# 45000/45000 [==============================] - 28s 624us/step - loss: 0.8774 - accuracy: 0.9958 - val_loss: 0.8729 - val_accuracy: 0.9916
# Epoch 11/30
# 45000/45000 [==============================] - 28s 618us/step - loss: 0.8178 - accuracy: 0.9959 - val_loss: 0.8223 - val_accuracy: 0.9908
# Epoch 12/30
# 45000/45000 [==============================] - 28s 624us/step - loss: 0.7631 - accuracy: 0.9964 - val_loss: 0.7824 - val_accuracy: 0.9895
# Epoch 13/30
# 45000/45000 [==============================] - 28s 620us/step - loss: 0.7099 - accuracy: 0.9972 - val_loss: 0.7329 - val_accuracy: 0.9901
# Epoch 14/30
# 45000/45000 [==============================] - 28s 626us/step - loss: 0.6634 - accuracy: 0.9973 - val_loss: 0.7170 - val_accuracy: 0.9849
# Epoch 15/30
# 45000/45000 [==============================] - 28s 624us/step - loss: 0.6177 - accuracy: 0.9976 - val_loss: 0.6265 - val_accuracy: 0.9929
# Epoch 16/30
# 45000/45000 [==============================] - 28s 626us/step - loss: 0.5793 - accuracy: 0.9969 - val_loss: 0.6273 - val_accuracy: 0.9861
# Epoch 17/30
# 45000/45000 [==============================] - 28s 625us/step - loss: 0.5390 - accuracy: 0.9979 - val_loss: 0.5555 - val_accuracy: 0.9921
# Epoch 18/30
# 45000/45000 [==============================] - 28s 626us/step - loss: 0.5024 - accuracy: 0.9983 - val_loss: 0.5214 - val_accuracy: 0.9919
# Epoch 19/30
# 45000/45000 [==============================] - 28s 626us/step - loss: 0.4704 - accuracy: 0.9980 - val_loss: 0.4859 - val_accuracy: 0.9930
# Epoch 20/30
# 45000/45000 [==============================] - 28s 626us/step - loss: 0.4387 - accuracy: 0.9979 - val_loss: 0.4534 - val_accuracy: 0.9936
# Epoch 21/30
# 45000/45000 [==============================] - 28s 624us/step - loss: 0.4094 - accuracy: 0.9982 - val_loss: 0.4422 - val_accuracy: 0.9905
# Epoch 22/30
# 45000/45000 [==============================] - 28s 625us/step - loss: 0.3838 - accuracy: 0.9980 - val_loss: 0.4094 - val_accuracy: 0.9919
# Epoch 23/30
# 45000/45000 [==============================] - 28s 626us/step - loss: 0.3594 - accuracy: 0.9980 - val_loss: 0.4024 - val_accuracy: 0.9897
# Epoch 24/30
# 45000/45000 [==============================] - 28s 623us/step - loss: 0.3342 - accuracy: 0.9985 - val_loss: 0.3692 - val_accuracy: 0.9913
# Epoch 25/30
# 45000/45000 [==============================] - 28s 625us/step - loss: 0.3178 - accuracy: 0.9972 - val_loss: 0.3604 - val_accuracy: 0.9896
# Epoch 26/30
# 45000/45000 [==============================] - 28s 625us/step - loss: 0.2951 - accuracy: 0.9978 - val_loss: 0.3365 - val_accuracy: 0.9900
# Epoch 27/30
# 45000/45000 [==============================] - 28s 625us/step - loss: 0.2730 - accuracy: 0.9986 - val_loss: 0.3164 - val_accuracy: 0.9906
# Epoch 28/30
# 45000/45000 [==============================] - 28s 626us/step - loss: 0.2583 - accuracy: 0.9980 - val_loss: 0.3086 - val_accuracy: 0.9896
# Epoch 29/30
# 45000/45000 [==============================] - 28s 624us/step - loss: 0.2415 - accuracy: 0.9980 - val_loss: 0.2812 - val_accuracy: 0.9911
# Epoch 30/30
# 45000/45000 [==============================] - 28s 625us/step - loss: 0.2241 - accuracy: 0.9988 - val_loss: 0.3091 - val_accuracy: 0.9847

# %%
epochs = 30
predictions3, history3 = run_vgg16()
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/30
# 45000/45000 [==============================] - 27s 608us/step - loss: 0.2103 - accuracy: 0.9987 - val_loss: 0.2392 - val_accuracy: 0.9929
# Epoch 2/30
# 45000/45000 [==============================] - 28s 612us/step - loss: 0.1966 - accuracy: 0.9988 - val_loss: 0.2578 - val_accuracy: 0.9870
# Epoch 3/30
# 45000/45000 [==============================] - 28s 613us/step - loss: 0.1834 - accuracy: 0.9988 - val_loss: 0.2276 - val_accuracy: 0.9911
# Epoch 4/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.1731 - accuracy: 0.9985 - val_loss: 0.2239 - val_accuracy: 0.9899
# Epoch 5/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.1620 - accuracy: 0.9985 - val_loss: 0.2068 - val_accuracy: 0.9913
# Epoch 6/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.1511 - accuracy: 0.9990 - val_loss: 0.1829 - val_accuracy: 0.9934
# Epoch 7/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.1419 - accuracy: 0.9986 - val_loss: 0.1790 - val_accuracy: 0.9924
# Epoch 8/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.1320 - accuracy: 0.9990 - val_loss: 0.1845 - val_accuracy: 0.9908
# Epoch 9/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.1258 - accuracy: 0.9986 - val_loss: 0.1705 - val_accuracy: 0.9921
# Epoch 10/30
# 45000/45000 [==============================] - 28s 613us/step - loss: 0.1189 - accuracy: 0.9982 - val_loss: 0.1648 - val_accuracy: 0.9917
# Epoch 11/30
# 45000/45000 [==============================] - 28s 618us/step - loss: 0.1124 - accuracy: 0.9984 - val_loss: 0.1568 - val_accuracy: 0.9917
# Epoch 12/30
# 45000/45000 [==============================] - 28s 617us/step - loss: 0.1046 - accuracy: 0.9988 - val_loss: 0.1429 - val_accuracy: 0.9929
# Epoch 13/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0987 - accuracy: 0.9986 - val_loss: 0.1548 - val_accuracy: 0.9906
# Epoch 14/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0915 - accuracy: 0.9991 - val_loss: 0.1434 - val_accuracy: 0.9898
# Epoch 15/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0860 - accuracy: 0.9990 - val_loss: 0.1203 - val_accuracy: 0.9943
# Epoch 16/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0807 - accuracy: 0.9991 - val_loss: 0.1251 - val_accuracy: 0.9916
# Epoch 17/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0787 - accuracy: 0.9986 - val_loss: 0.1220 - val_accuracy: 0.9917
# Epoch 18/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.0721 - accuracy: 0.9988 - val_loss: 0.1113 - val_accuracy: 0.9935
# Epoch 19/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0676 - accuracy: 0.9990 - val_loss: 0.1174 - val_accuracy: 0.9923
# Epoch 20/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0630 - accuracy: 0.9993 - val_loss: 0.1097 - val_accuracy: 0.9925
# Epoch 21/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0607 - accuracy: 0.9991 - val_loss: 0.1193 - val_accuracy: 0.9911
# Epoch 22/30
# 45000/45000 [==============================] - 28s 613us/step - loss: 0.0568 - accuracy: 0.9990 - val_loss: 0.0930 - val_accuracy: 0.9938
# Epoch 23/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.0525 - accuracy: 0.9995 - val_loss: 0.0931 - val_accuracy: 0.9938
# Epoch 24/30
# 45000/45000 [==============================] - 27s 606us/step - loss: 0.0499 - accuracy: 0.9994 - val_loss: 0.1067 - val_accuracy: 0.9923
# Epoch 25/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0488 - accuracy: 0.9990 - val_loss: 0.1019 - val_accuracy: 0.9904
# Epoch 26/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0432 - accuracy: 0.9995 - val_loss: 0.0813 - val_accuracy: 0.9939
# Epoch 27/30
# 45000/45000 [==============================] - 28s 612us/step - loss: 0.0425 - accuracy: 0.9991 - val_loss: 0.0799 - val_accuracy: 0.9933
# Epoch 28/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0400 - accuracy: 0.9995 - val_loss: 0.0785 - val_accuracy: 0.9940
# Epoch 29/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.0381 - accuracy: 0.9992 - val_loss: 0.0746 - val_accuracy: 0.9942
# Epoch 30/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0351 - accuracy: 0.9996 - val_loss: 0.0723 - val_accuracy: 0.9940

# %%
epochs = 30
predictions4, history4 = run_vgg16()
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/30
# 45000/45000 [==============================] - 27s 611us/step - loss: 0.0328 - accuracy: 0.9996 - val_loss: 0.0881 - val_accuracy: 0.9917
# Epoch 2/30
# 45000/45000 [==============================] - 28s 613us/step - loss: 0.0313 - accuracy: 0.9996 - val_loss: 0.0788 - val_accuracy: 0.9927
# Epoch 3/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0296 - accuracy: 0.9996 - val_loss: 0.0781 - val_accuracy: 0.9928
# Epoch 4/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0286 - accuracy: 0.9992 - val_loss: 0.0859 - val_accuracy: 0.9909
# Epoch 5/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.0292 - accuracy: 0.9989 - val_loss: 0.0944 - val_accuracy: 0.9917
# Epoch 6/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0279 - accuracy: 0.9990 - val_loss: 0.0679 - val_accuracy: 0.9938
# Epoch 7/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0264 - accuracy: 0.9991 - val_loss: 0.0973 - val_accuracy: 0.9893
# Epoch 8/30
# 45000/45000 [==============================] - 28s 617us/step - loss: 0.0272 - accuracy: 0.9988 - val_loss: 0.1146 - val_accuracy: 0.9863
# Epoch 9/30
# 45000/45000 [==============================] - 28s 617us/step - loss: 0.0255 - accuracy: 0.9991 - val_loss: 0.1006 - val_accuracy: 0.9883
# Epoch 10/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0227 - accuracy: 0.9994 - val_loss: 0.0690 - val_accuracy: 0.9930
# Epoch 11/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0217 - accuracy: 0.9995 - val_loss: 0.0750 - val_accuracy: 0.9920
# Epoch 12/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.0213 - accuracy: 0.9993 - val_loss: 0.0721 - val_accuracy: 0.9921
# Epoch 13/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0201 - accuracy: 0.9993 - val_loss: 0.0636 - val_accuracy: 0.9933
# Epoch 14/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0197 - accuracy: 0.9992 - val_loss: 0.0704 - val_accuracy: 0.9925
# Epoch 15/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.0193 - accuracy: 0.9994 - val_loss: 0.0813 - val_accuracy: 0.9896
# Epoch 16/30
# 45000/45000 [==============================] - 28s 612us/step - loss: 0.0173 - accuracy: 0.9994 - val_loss: 0.0561 - val_accuracy: 0.9935
# Epoch 17/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0157 - accuracy: 0.9997 - val_loss: 0.0675 - val_accuracy: 0.9925
# Epoch 18/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0165 - accuracy: 0.9993 - val_loss: 0.0672 - val_accuracy: 0.9917
# Epoch 19/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0151 - accuracy: 0.9996 - val_loss: 0.0603 - val_accuracy: 0.9937
# Epoch 20/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0133 - accuracy: 0.9998 - val_loss: 0.0569 - val_accuracy: 0.9939
# Epoch 21/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0135 - accuracy: 0.9996 - val_loss: 0.0520 - val_accuracy: 0.9943
# Epoch 22/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.0131 - accuracy: 0.9995 - val_loss: 0.0543 - val_accuracy: 0.9939
# Epoch 23/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0137 - accuracy: 0.9992 - val_loss: 0.0581 - val_accuracy: 0.9941
# Epoch 24/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0142 - accuracy: 0.9990 - val_loss: 0.0706 - val_accuracy: 0.9925
# Epoch 25/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0148 - accuracy: 0.9988 - val_loss: 0.0687 - val_accuracy: 0.9921
# Epoch 26/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0140 - accuracy: 0.9992 - val_loss: 0.0613 - val_accuracy: 0.9929
# Epoch 27/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.0142 - accuracy: 0.9991 - val_loss: 0.0632 - val_accuracy: 0.9927
# Epoch 28/30
# 45000/45000 [==============================] - 28s 616us/step - loss: 0.0128 - accuracy: 0.9994 - val_loss: 0.0610 - val_accuracy: 0.9927
# Epoch 29/30
# 45000/45000 [==============================] - 28s 615us/step - loss: 0.0123 - accuracy: 0.9994 - val_loss: 0.0586 - val_accuracy: 0.9925
# Epoch 30/30
# 45000/45000 [==============================] - 28s 614us/step - loss: 0.0107 - accuracy: 0.9998 - val_loss: 0.0508 - val_accuracy: 0.9940

# %%
fig1 = plt.figure(figsize = (12,10))
ax1 = fig1.add_subplot(2,2,1)
ax2 = fig1.add_subplot(2,2,2)

ax1.plot(np.arange(1,151), history.val_losses+history1.val_losses+history2.val_losses+history3.val_losses+history4.val_losses)
ax1.set(xlabel='Epochs', ylabel='Validation Loss',
       title='Epochs vs. Validation Loss')
ax2.plot(np.arange(1,151), history.losses+history1.losses+history2.losses+history3.losses+history4.losses)
ax2.set(xlabel='Epochs', ylabel='Training Loss',
       title='Epochs vs. Training Loss')
plt.show()

# %%
fig1 = plt.figure(figsize = (12,10))
ax1 = fig1.add_subplot(2,2,1)
ax2 = fig1.add_subplot(2,2,2)

ax1.plot(np.arange(1,151), history.val_accuracy+history1.val_accuracy+history2.val_accuracy+history3.val_accuracy+history4.val_accuracy)
ax1.set(xlabel='Epochs', ylabel='Validation Accuracy',
       title='Epochs vs. Validation Accuracy')
ax2.plot(np.arange(1,151), history.accuracy+history1.accuracy+history2.accuracy+history3.accuracy+history4.accuracy)
ax2.set(xlabel='Epochs', ylabel='Training Accuracy',
       title='Epochs vs. Training Accuracy')
plt.show()

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 99.28 %

# %%
import h5py
model.save_weights('mnist_trans_weights.h5')
vggmodel_json = model.to_json()
with open ("mnist_trans.json", "w") as json_file:
    json_file.write(vggmodel_json)

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test_prepro[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test_prepro[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [5 4 8 2 2]
# classified as: [3 8 2 4 1]
# True:          [4 2 3 6 6]
# classified as: [9 7 5 0 5]
