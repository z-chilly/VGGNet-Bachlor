# %%
from __future__ import print_function
import imageio, keras
import matplotlib.pyplot as plt
import numpy as np
import os
import sys
import tarfile
from IPython.display import display, Image
from sklearn.linear_model import LogisticRegression
from six.moves.urllib.request import urlretrieve
from six.moves import cPickle as pickle

import tensorflow as tf
from keras import backend as K

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="1"
#This will make it so that only the 0th GPU is visible to TensorFlow.
#In your case, you can choose any in the range [0, 3].
#If you wanted, for example, the 0th and 2nd GPUs to both be visible, replace "0" with "0,2"
GPU=True
CPU=False
num_cores = 4

if GPU:
    num_GPU = 1
    num_CPU = 1
if CPU:
    num_CPU = 1
    num_GPU = 0

config = tf.ConfigProto(intra_op_parallelism_threads=num_cores,\
        inter_op_parallelism_threads=num_cores, allow_soft_placement=True,\
        device_count = {'CPU' : num_CPU, 'GPU' : num_GPU},\
#        gpu_options=tf.GPUOptions(per_process_gpu_memory_fraction=0.5))
                       )
session = tf.Session(config=config)
K.set_session(session)
# %matplotlib inline

# %%
from keras.datasets import cifar10

num_classes=10

img_rows, img_cols = 32, 32
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    input_shape = (3, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('train_dataset shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train_onehot = keras.utils.to_categorical(y_train, num_classes)
y_test_onehot = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 8s 0us/step
# train_dataset shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
# Copy data to 3 channels and resample to get 56x56 images
# VGG needs atleast 48x48, so resample
# Center and resample diffraction array to desired pixel spacing
from scipy.ndimage.interpolation import zoom

def resample(diff3D, Nx, Ny): 
    nx, ny, nz = diff3D.shape
    diff3D=zoom(diff3D, (float(Nx)/nx,float(Ny)/ny, 1), order=1)
    return diff3D


from tqdm import tqdm
def copy3channels(input_data):
    dims = input_data.shape
    # dataset3 = np.zeros((dims[0],28,28,3),float)
    # for i in tqdm(range(dims[0])):
    #    dataset3[i,:,:,0], dataset3[i,:,:,1], dataset3[i,:,:,2] = input_data[i,:,:,0], input_data[i,:,:,0], input_data[i,:,:,0]
    data=[]
    for i in tqdm(range(dims[0])):
        tmp=resample(input_data[i,:,:,:],64,64)
        data.append(tmp)
    return np.array(data)

# %%
x_train_prepro = copy3channels(x_train)
x_test_prepro = copy3channels(x_test)
# Out:
# 100%|██████████| 50000/50000 [00:31<00:00, 1585.05it/s]
# 100%|██████████| 10000/10000 [00:06<00:00, 1660.02it/s]

# %%
x_train_prepro.shape
# Out:
# (50000, 64, 64, 3)

# %%
K.clear_session()

from keras.layers import Conv2D, MaxPool2D
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras import backend as K
from keras.utils import to_categorical

import keras
from keras.applications.vgg16 import VGG16
from keras.optimizers import SGD
from keras.models import Model, load_model
from keras.layers import GlobalMaxPooling2D
from keras.utils import np_utils

#base_model.layers.pop() 
#Pop out the current logistic layer
base_model = VGG16(input_shape=(64, 64, 3), weights='imagenet', include_top=False)
for layers in base_model.layers:
    layers.trainable = False

tmp = Flatten()(base_model.output)
#Add a fully connected layer
tmp = Dense(4096, activation='relu',name='fc1')(tmp)
tmp = Dropout(0.5)(tmp)
tmp = Dense(4096, activation='relu',name='fc2')(tmp)
tmp = Dropout(0.5)(tmp)
predictions = Dense(10, activation='softmax')(tmp)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)
    
sgd = SGD(lr=1e-3, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

#Save model every epoch
# checkpoints=keras.callbacks.ModelCheckpoint('vgg_weights/weights.{epoch:02d}.hdf5', monitor='val_loss', 
                                # verbose=0, save_best_only=False, save_weights_only=False, mode='auto', period=1)

# print (model.summary())


# history=model.fit(x_train_prepro, y_train_onehot,
                #np_utils.to_categorical(labels,n_labels),  
                # batch_size=batch_size, epochs=epochs, verbose=1, validation_split = 0.25, callbacks=[checkpoints])

# %%
## Callback for loss logging per epoch
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
batch_size=128
epochs=300

class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.val_losses = []
        self.accuracy = []
        self.val_accuracy = []
        
    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))
        self.accuracy.append(logs.get('accuracy'))
        self.val_accuracy.append(logs.get('val_accuracy'))

early_stopping = EarlyStopping(monitor='val_loss', patience=100, verbose=1, mode='auto')

def run_vgg16():
    
    history = LossHistory()
    model.fit(x_train_prepro, y_train_onehot, batch_size=batch_size, epochs=epochs,
              validation_split=0.15, verbose=1, shuffle=True, callbacks=[history, early_stopping])
    

    predictions = model.predict(x_test_prepro, verbose=0)
    return predictions, history

def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
predictions, history = run_vgg16()
print(model.summary())
# Out:
# Train on 42500 samples, validate on 7500 samples
# Epoch 1/300
# 42500/42500 [==============================] - 20s 462us/step - loss: 1.8641 - accuracy: 0.3427 - val_loss: 1.4835 - val_accuracy: 0.4945
# Epoch 2/300
# 42500/42500 [==============================] - 18s 434us/step - loss: 1.4659 - accuracy: 0.4913 - val_loss: 1.2737 - val_accuracy: 0.5689
# Epoch 3/300
# 42500/42500 [==============================] - 18s 428us/step - loss: 1.3253 - accuracy: 0.5424 - val_loss: 1.1806 - val_accuracy: 0.5947
# Epoch 4/300
# 42500/42500 [==============================] - 19s 435us/step - loss: 1.2460 - accuracy: 0.5651 - val_loss: 1.1367 - val_accuracy: 0.6044
# Epoch 5/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 1.1927 - accuracy: 0.5843 - val_loss: 1.1198 - val_accuracy: 0.6113
# Epoch 6/300
# 42500/42500 [==============================] - 18s 431us/step - loss: 1.1529 - accuracy: 0.5976 - val_loss: 1.0565 - val_accuracy: 0.6348
# Epoch 7/300
# 42500/42500 [==============================] - 18s 429us/step - loss: 1.1153 - accuracy: 0.6124 - val_loss: 1.0312 - val_accuracy: 0.6397
# Epoch 8/300
# 42500/42500 [==============================] - 18s 432us/step - loss: 1.0903 - accuracy: 0.6214 - val_loss: 1.0114 - val_accuracy: 0.6493
# Epoch 9/300
# 42500/42500 [==============================] - 19s 437us/step - loss: 1.0636 - accuracy: 0.6284 - val_loss: 0.9951 - val_accuracy: 0.6536
# Epoch 10/300
# 42500/42500 [==============================] - 18s 428us/step - loss: 1.0463 - accuracy: 0.6374 - val_loss: 1.0544 - val_accuracy: 0.6332
# Epoch 11/300
# 42500/42500 [==============================] - 18s 433us/step - loss: 1.0368 - accuracy: 0.6374 - val_loss: 0.9732 - val_accuracy: 0.6601
# Epoch 12/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 1.0097 - accuracy: 0.6480 - val_loss: 0.9785 - val_accuracy: 0.6544
# Epoch 13/300
# 42500/42500 [==============================] - 18s 431us/step - loss: 0.9964 - accuracy: 0.6560 - val_loss: 0.9707 - val_accuracy: 0.6625
# Epoch 14/300
# 42500/42500 [==============================] - 18s 428us/step - loss: 0.9822 - accuracy: 0.6576 - val_loss: 0.9499 - val_accuracy: 0.6656
# Epoch 15/300
# 42500/42500 [==============================] - 18s 429us/step - loss: 0.9680 - accuracy: 0.6619 - val_loss: 0.9581 - val_accuracy: 0.6665
# Epoch 16/300
# 42500/42500 [==============================] - 18s 434us/step - loss: 0.9606 - accuracy: 0.6635 - val_loss: 0.9350 - val_accuracy: 0.6729
# Epoch 17/300
# 42500/42500 [==============================] - 18s 431us/step - loss: 0.9461 - accuracy: 0.6704 - val_loss: 0.9140 - val_accuracy: 0.6820
# Epoch 18/300
# 42500/42500 [==============================] - 18s 427us/step - loss: 0.9377 - accuracy: 0.6724 - val_loss: 0.9032 - val_accuracy: 0.6884
# Epoch 19/300
# 42500/42500 [==============================] - 18s 434us/step - loss: 0.9196 - accuracy: 0.6786 - val_loss: 0.8952 - val_accuracy: 0.6881
# Epoch 20/300
# 42500/42500 [==============================] - 18s 434us/step - loss: 0.9152 - accuracy: 0.6807 - val_loss: 0.9268 - val_accuracy: 0.6783
# Epoch 21/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.9066 - accuracy: 0.6844 - val_loss: 0.9058 - val_accuracy: 0.6853
# Epoch 22/300
# 42500/42500 [==============================] - 18s 421us/step - loss: 0.8968 - accuracy: 0.6882 - val_loss: 0.8933 - val_accuracy: 0.6880
# Epoch 23/300
# 42500/42500 [==============================] - 18s 433us/step - loss: 0.8849 - accuracy: 0.6891 - val_loss: 1.0264 - val_accuracy: 0.6447
# Epoch 24/300
# 42500/42500 [==============================] - 18s 432us/step - loss: 0.8902 - accuracy: 0.6875 - val_loss: 0.8827 - val_accuracy: 0.6939
# Epoch 25/300
# 42500/42500 [==============================] - 18s 434us/step - loss: 0.8699 - accuracy: 0.6976 - val_loss: 0.8778 - val_accuracy: 0.6983
# Epoch 26/300
# 42500/42500 [==============================] - 18s 425us/step - loss: 0.8620 - accuracy: 0.6992 - val_loss: 0.8890 - val_accuracy: 0.6904
# Epoch 27/300
# 42500/42500 [==============================] - 18s 429us/step - loss: 0.8547 - accuracy: 0.7022 - val_loss: 0.8614 - val_accuracy: 0.7012
# Epoch 28/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.8425 - accuracy: 0.7050 - val_loss: 0.8564 - val_accuracy: 0.7079
# Epoch 29/300
# 42500/42500 [==============================] - 18s 428us/step - loss: 0.8406 - accuracy: 0.7071 - val_loss: 0.8623 - val_accuracy: 0.7015
# Epoch 30/300
# 42500/42500 [==============================] - 19s 446us/step - loss: 0.8312 - accuracy: 0.7087 - val_loss: 0.8539 - val_accuracy: 0.7057
# Epoch 31/300
# 42500/42500 [==============================] - 19s 446us/step - loss: 0.8247 - accuracy: 0.7122 - val_loss: 0.8608 - val_accuracy: 0.7071
# Epoch 32/300
# 42500/42500 [==============================] - 19s 450us/step - loss: 0.8192 - accuracy: 0.7108 - val_loss: 0.8728 - val_accuracy: 0.7012
# Epoch 33/300
# 42500/42500 [==============================] - 19s 443us/step - loss: 0.8169 - accuracy: 0.7143 - val_loss: 0.8572 - val_accuracy: 0.7084
# Epoch 34/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 0.8061 - accuracy: 0.7174 - val_loss: 0.8701 - val_accuracy: 0.6968
# Epoch 35/300
# 42500/42500 [==============================] - 19s 449us/step - loss: 0.8004 - accuracy: 0.7223 - val_loss: 0.8408 - val_accuracy: 0.7069
# Epoch 36/300
# 42500/42500 [==============================] - 18s 434us/step - loss: 0.7928 - accuracy: 0.7236 - val_loss: 0.8857 - val_accuracy: 0.6899
# Epoch 37/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.7870 - accuracy: 0.7248 - val_loss: 0.9355 - val_accuracy: 0.6801
# Epoch 38/300
# 42500/42500 [==============================] - 19s 444us/step - loss: 0.7931 - accuracy: 0.7204 - val_loss: 0.8838 - val_accuracy: 0.6932
# Epoch 39/300
# 42500/42500 [==============================] - 18s 435us/step - loss: 0.7775 - accuracy: 0.7251 - val_loss: 0.8366 - val_accuracy: 0.7085
# Epoch 40/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.7704 - accuracy: 0.7306 - val_loss: 0.8422 - val_accuracy: 0.7103
# Epoch 41/300
# 42500/42500 [==============================] - 18s 435us/step - loss: 0.7592 - accuracy: 0.7352 - val_loss: 0.8948 - val_accuracy: 0.6960
# Epoch 42/300
# 42500/42500 [==============================] - 19s 443us/step - loss: 0.7665 - accuracy: 0.7336 - val_loss: 0.8959 - val_accuracy: 0.6877
# Epoch 43/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 0.7674 - accuracy: 0.7319 - val_loss: 0.8164 - val_accuracy: 0.7177
# Epoch 44/300
# 42500/42500 [==============================] - 19s 443us/step - loss: 0.7539 - accuracy: 0.7364 - val_loss: 0.8450 - val_accuracy: 0.7144
# Epoch 45/300
# 42500/42500 [==============================] - 19s 436us/step - loss: 0.7510 - accuracy: 0.7397 - val_loss: 0.8222 - val_accuracy: 0.7167
# Epoch 46/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 0.7377 - accuracy: 0.7416 - val_loss: 0.8634 - val_accuracy: 0.7056
# Epoch 47/300
# 42500/42500 [==============================] - 19s 451us/step - loss: 0.7440 - accuracy: 0.7395 - val_loss: 0.8307 - val_accuracy: 0.7139
# Epoch 48/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 0.7346 - accuracy: 0.7408 - val_loss: 0.8290 - val_accuracy: 0.7151
# Epoch 49/300
# 42500/42500 [==============================] - 19s 449us/step - loss: 0.7252 - accuracy: 0.7454 - val_loss: 0.8748 - val_accuracy: 0.6919
# Epoch 50/300
# 42500/42500 [==============================] - 19s 448us/step - loss: 0.7199 - accuracy: 0.7479 - val_loss: 0.8005 - val_accuracy: 0.7249
# Epoch 51/300
# 42500/42500 [==============================] - 19s 444us/step - loss: 0.7100 - accuracy: 0.7524 - val_loss: 0.8656 - val_accuracy: 0.7009
# Epoch 52/300
# 42500/42500 [==============================] - 18s 433us/step - loss: 0.7128 - accuracy: 0.7509 - val_loss: 0.8549 - val_accuracy: 0.7023
# Epoch 53/300
# 42500/42500 [==============================] - 19s 438us/step - loss: 0.7042 - accuracy: 0.7526 - val_loss: 0.8095 - val_accuracy: 0.7225
# Epoch 54/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.6989 - accuracy: 0.7532 - val_loss: 0.8267 - val_accuracy: 0.7139
# Epoch 55/300
# 42500/42500 [==============================] - 19s 438us/step - loss: 0.6931 - accuracy: 0.7557 - val_loss: 0.8087 - val_accuracy: 0.7213
# Epoch 56/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.6876 - accuracy: 0.7595 - val_loss: 0.8132 - val_accuracy: 0.7229
# Epoch 57/300
# 42500/42500 [==============================] - 19s 437us/step - loss: 0.6846 - accuracy: 0.7587 - val_loss: 0.7925 - val_accuracy: 0.7276
# Epoch 58/300
# 42500/42500 [==============================] - 19s 436us/step - loss: 0.6769 - accuracy: 0.7645 - val_loss: 0.7993 - val_accuracy: 0.7285
# Epoch 59/300
# 42500/42500 [==============================] - 19s 451us/step - loss: 0.6689 - accuracy: 0.7660 - val_loss: 0.7909 - val_accuracy: 0.7292
# Epoch 60/300
# 42500/42500 [==============================] - 19s 444us/step - loss: 0.6621 - accuracy: 0.7693 - val_loss: 0.8029 - val_accuracy: 0.7245
# Epoch 61/300
# 42500/42500 [==============================] - 19s 446us/step - loss: 0.6570 - accuracy: 0.7703 - val_loss: 0.8256 - val_accuracy: 0.7199
# Epoch 62/300
# 42500/42500 [==============================] - 19s 452us/step - loss: 0.6580 - accuracy: 0.7699 - val_loss: 0.7994 - val_accuracy: 0.7288
# Epoch 63/300
# 42500/42500 [==============================] - 19s 443us/step - loss: 0.6528 - accuracy: 0.7716 - val_loss: 0.7905 - val_accuracy: 0.7285
# Epoch 64/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.6463 - accuracy: 0.7721 - val_loss: 0.8217 - val_accuracy: 0.7197
# Epoch 65/300
# 42500/42500 [==============================] - 19s 452us/step - loss: 0.6376 - accuracy: 0.7762 - val_loss: 0.7830 - val_accuracy: 0.7312
# Epoch 66/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 0.6296 - accuracy: 0.7785 - val_loss: 0.7930 - val_accuracy: 0.7325
# Epoch 67/300
# 42500/42500 [==============================] - 19s 448us/step - loss: 0.6263 - accuracy: 0.7803 - val_loss: 0.8466 - val_accuracy: 0.7140
# Epoch 68/300
# 42500/42500 [==============================] - 19s 436us/step - loss: 0.6387 - accuracy: 0.7756 - val_loss: 0.8273 - val_accuracy: 0.7183
# Epoch 69/300
# 42500/42500 [==============================] - 19s 447us/step - loss: 0.6292 - accuracy: 0.7815 - val_loss: 0.7900 - val_accuracy: 0.7315
# Epoch 70/300
# 42500/42500 [==============================] - 19s 447us/step - loss: 0.6175 - accuracy: 0.7836 - val_loss: 0.8129 - val_accuracy: 0.7240
# Epoch 71/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 0.6190 - accuracy: 0.7836 - val_loss: 0.7770 - val_accuracy: 0.7360
# Epoch 72/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.6080 - accuracy: 0.7856 - val_loss: 0.7751 - val_accuracy: 0.7399
# Epoch 73/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 0.6047 - accuracy: 0.7901 - val_loss: 0.7811 - val_accuracy: 0.7383
# Epoch 74/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.5975 - accuracy: 0.7907 - val_loss: 0.8515 - val_accuracy: 0.7144
# Epoch 75/300
# 42500/42500 [==============================] - 19s 436us/step - loss: 0.6108 - accuracy: 0.7872 - val_loss: 0.7869 - val_accuracy: 0.7316
# Epoch 76/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 0.5943 - accuracy: 0.7923 - val_loss: 0.7830 - val_accuracy: 0.7339
# Epoch 77/300
# 42500/42500 [==============================] - 19s 456us/step - loss: 0.5845 - accuracy: 0.7962 - val_loss: 0.8880 - val_accuracy: 0.7033
# Epoch 78/300
# 42500/42500 [==============================] - 19s 448us/step - loss: 0.5919 - accuracy: 0.7918 - val_loss: 0.8397 - val_accuracy: 0.7180
# Epoch 79/300
# 42500/42500 [==============================] - 19s 448us/step - loss: 0.5924 - accuracy: 0.7910 - val_loss: 0.8586 - val_accuracy: 0.7080
# Epoch 80/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 0.5933 - accuracy: 0.7932 - val_loss: 0.7786 - val_accuracy: 0.7331
# Epoch 81/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.5732 - accuracy: 0.7983 - val_loss: 0.8486 - val_accuracy: 0.7137
# Epoch 82/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 0.5782 - accuracy: 0.7959 - val_loss: 0.7836 - val_accuracy: 0.7313
# Epoch 83/300
# 42500/42500 [==============================] - 19s 450us/step - loss: 0.5687 - accuracy: 0.8003 - val_loss: 0.7815 - val_accuracy: 0.7332
# Epoch 84/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 0.5619 - accuracy: 0.8031 - val_loss: 0.9085 - val_accuracy: 0.7016
# Epoch 85/300
# 42500/42500 [==============================] - 19s 449us/step - loss: 0.5663 - accuracy: 0.8010 - val_loss: 0.9504 - val_accuracy: 0.6901
# Epoch 86/300
# 42500/42500 [==============================] - 19s 445us/step - loss: 0.5824 - accuracy: 0.7960 - val_loss: 0.8383 - val_accuracy: 0.7265
# Epoch 87/300
# 42500/42500 [==============================] - 19s 445us/step - loss: 0.5694 - accuracy: 0.7998 - val_loss: 0.7806 - val_accuracy: 0.7339
# Epoch 88/300
# 42500/42500 [==============================] - 19s 436us/step - loss: 0.5625 - accuracy: 0.8047 - val_loss: 0.7786 - val_accuracy: 0.7359
# Epoch 89/300
# 42500/42500 [==============================] - 18s 435us/step - loss: 0.5451 - accuracy: 0.8104 - val_loss: 0.7841 - val_accuracy: 0.7340
# Epoch 90/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 0.5479 - accuracy: 0.8074 - val_loss: 0.7813 - val_accuracy: 0.7344
# Epoch 91/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.5471 - accuracy: 0.8088 - val_loss: 0.8136 - val_accuracy: 0.7264
# Epoch 92/300
# 42500/42500 [==============================] - 19s 450us/step - loss: 0.5476 - accuracy: 0.8069 - val_loss: 0.7901 - val_accuracy: 0.7345
# Epoch 93/300
# 42500/42500 [==============================] - 19s 443us/step - loss: 0.5310 - accuracy: 0.8124 - val_loss: 0.7747 - val_accuracy: 0.7396
# Epoch 94/300
# 42500/42500 [==============================] - 19s 437us/step - loss: 0.5275 - accuracy: 0.8151 - val_loss: 0.8954 - val_accuracy: 0.7056
# Epoch 95/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.5453 - accuracy: 0.8086 - val_loss: 0.7732 - val_accuracy: 0.7413
# Epoch 96/300
# 42500/42500 [==============================] - 19s 447us/step - loss: 0.5304 - accuracy: 0.8162 - val_loss: 0.7733 - val_accuracy: 0.7424
# Epoch 97/300
# 42500/42500 [==============================] - 19s 438us/step - loss: 0.5201 - accuracy: 0.8177 - val_loss: 0.8360 - val_accuracy: 0.7239
# Epoch 98/300
# 42500/42500 [==============================] - 19s 448us/step - loss: 0.5321 - accuracy: 0.8133 - val_loss: 0.8691 - val_accuracy: 0.7128
# Epoch 99/300
# 42500/42500 [==============================] - 19s 444us/step - loss: 0.5275 - accuracy: 0.8149 - val_loss: 0.8014 - val_accuracy: 0.7332
# Epoch 100/300
# 42500/42500 [==============================] - 19s 448us/step - loss: 0.5118 - accuracy: 0.8213 - val_loss: 0.7881 - val_accuracy: 0.7371
# Epoch 101/300
# 42500/42500 [==============================] - 19s 448us/step - loss: 0.5028 - accuracy: 0.8242 - val_loss: 0.8693 - val_accuracy: 0.7149
# Epoch 102/300
# 42500/42500 [==============================] - 19s 448us/step - loss: 0.5090 - accuracy: 0.8214 - val_loss: 0.8529 - val_accuracy: 0.7221
# Epoch 103/300
# 42500/42500 [==============================] - 19s 447us/step - loss: 0.5083 - accuracy: 0.8226 - val_loss: 0.7756 - val_accuracy: 0.7413
# Epoch 104/300
# 42500/42500 [==============================] - 19s 445us/step - loss: 0.4931 - accuracy: 0.8264 - val_loss: 0.7778 - val_accuracy: 0.7412
# Epoch 105/300
# 42500/42500 [==============================] - 19s 445us/step - loss: 0.4863 - accuracy: 0.8313 - val_loss: 0.8807 - val_accuracy: 0.7163
# Epoch 106/300
# 42500/42500 [==============================] - 19s 446us/step - loss: 0.4988 - accuracy: 0.8245 - val_loss: 0.8022 - val_accuracy: 0.7349
# Epoch 107/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 0.4994 - accuracy: 0.8232 - val_loss: 0.7818 - val_accuracy: 0.7404
# Epoch 108/300
# 42500/42500 [==============================] - 19s 436us/step - loss: 0.4834 - accuracy: 0.8308 - val_loss: 0.8064 - val_accuracy: 0.7391
# Epoch 109/300
# 42500/42500 [==============================] - 19s 436us/step - loss: 0.4842 - accuracy: 0.8303 - val_loss: 0.8335 - val_accuracy: 0.7292
# Epoch 110/300
# 42500/42500 [==============================] - 19s 453us/step - loss: 0.4818 - accuracy: 0.8320 - val_loss: 0.7952 - val_accuracy: 0.7376
# Epoch 111/300
# 42500/42500 [==============================] - 19s 449us/step - loss: 0.4706 - accuracy: 0.8358 - val_loss: 0.8092 - val_accuracy: 0.7340
# Epoch 112/300
# 42500/42500 [==============================] - 19s 443us/step - loss: 0.4657 - accuracy: 0.8377 - val_loss: 0.8503 - val_accuracy: 0.7269
# Epoch 113/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.4775 - accuracy: 0.8326 - val_loss: 0.7757 - val_accuracy: 0.7456
# Epoch 114/300
# 42500/42500 [==============================] - 19s 443us/step - loss: 0.4590 - accuracy: 0.8395 - val_loss: 0.8180 - val_accuracy: 0.7356
# Epoch 115/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 0.4540 - accuracy: 0.8413 - val_loss: 0.8421 - val_accuracy: 0.7351
# Epoch 116/300
# 42500/42500 [==============================] - 19s 445us/step - loss: 0.4556 - accuracy: 0.8413 - val_loss: 0.9668 - val_accuracy: 0.7020
# Epoch 117/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.4742 - accuracy: 0.8344 - val_loss: 0.7983 - val_accuracy: 0.7409
# Epoch 118/300
# 42500/42500 [==============================] - 19s 447us/step - loss: 0.4589 - accuracy: 0.8387 - val_loss: 0.7819 - val_accuracy: 0.7469
# Epoch 119/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.4454 - accuracy: 0.8445 - val_loss: 0.8418 - val_accuracy: 0.7287
# Epoch 120/300
# 42500/42500 [==============================] - 18s 432us/step - loss: 0.4464 - accuracy: 0.8450 - val_loss: 0.7982 - val_accuracy: 0.7435
# Epoch 121/300
# 42500/42500 [==============================] - 18s 424us/step - loss: 0.4353 - accuracy: 0.8496 - val_loss: 0.8199 - val_accuracy: 0.7316
# Epoch 122/300
# 42500/42500 [==============================] - 18s 431us/step - loss: 0.4415 - accuracy: 0.8459 - val_loss: 0.7953 - val_accuracy: 0.7399
# Epoch 123/300
# 42500/42500 [==============================] - 18s 431us/step - loss: 0.4398 - accuracy: 0.8479 - val_loss: 0.7893 - val_accuracy: 0.7460
# Epoch 124/300
# 42500/42500 [==============================] - 18s 423us/step - loss: 0.4292 - accuracy: 0.8479 - val_loss: 1.0450 - val_accuracy: 0.6781
# Epoch 125/300
# 42500/42500 [==============================] - 18s 424us/step - loss: 0.4555 - accuracy: 0.8415 - val_loss: 0.7917 - val_accuracy: 0.7425
# Epoch 126/300
# 42500/42500 [==============================] - 18s 424us/step - loss: 0.4333 - accuracy: 0.8486 - val_loss: 0.8148 - val_accuracy: 0.7332
# Epoch 127/300
# 42500/42500 [==============================] - 18s 430us/step - loss: 0.4330 - accuracy: 0.8512 - val_loss: 0.8062 - val_accuracy: 0.7447
# Epoch 128/300
# 42500/42500 [==============================] - 18s 432us/step - loss: 0.4236 - accuracy: 0.8519 - val_loss: 0.8446 - val_accuracy: 0.7281
# Epoch 129/300
# 42500/42500 [==============================] - 19s 443us/step - loss: 0.4302 - accuracy: 0.8509 - val_loss: 0.8580 - val_accuracy: 0.7287
# Epoch 130/300
# 42500/42500 [==============================] - 19s 444us/step - loss: 0.4286 - accuracy: 0.8505 - val_loss: 0.7834 - val_accuracy: 0.7436
# Epoch 131/300
# 42500/42500 [==============================] - 18s 432us/step - loss: 0.4238 - accuracy: 0.8521 - val_loss: 0.7915 - val_accuracy: 0.7433
# Epoch 132/300
# 42500/42500 [==============================] - 18s 431us/step - loss: 0.4145 - accuracy: 0.8559 - val_loss: 1.0209 - val_accuracy: 0.6847
# Epoch 133/300
# 42500/42500 [==============================] - 19s 435us/step - loss: 0.4408 - accuracy: 0.8459 - val_loss: 0.8096 - val_accuracy: 0.7349
# Epoch 134/300
# 42500/42500 [==============================] - 18s 435us/step - loss: 0.4169 - accuracy: 0.8556 - val_loss: 0.8243 - val_accuracy: 0.7365
# Epoch 135/300
# 42500/42500 [==============================] - 18s 433us/step - loss: 0.4164 - accuracy: 0.8548 - val_loss: 0.8061 - val_accuracy: 0.7437
# Epoch 136/300
# 42500/42500 [==============================] - 18s 434us/step - loss: 0.4080 - accuracy: 0.8572 - val_loss: 0.7954 - val_accuracy: 0.7451
# Epoch 137/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 0.4007 - accuracy: 0.8591 - val_loss: 0.8128 - val_accuracy: 0.7397
# Epoch 138/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.4135 - accuracy: 0.8556 - val_loss: 0.7985 - val_accuracy: 0.7453
# Epoch 139/300
# 42500/42500 [==============================] - 19s 436us/step - loss: 0.3999 - accuracy: 0.8613 - val_loss: 0.7896 - val_accuracy: 0.7451
# Epoch 140/300
# 42500/42500 [==============================] - 19s 443us/step - loss: 0.3886 - accuracy: 0.8635 - val_loss: 0.8028 - val_accuracy: 0.7471
# Epoch 141/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 0.3871 - accuracy: 0.8656 - val_loss: 0.9039 - val_accuracy: 0.7175
# Epoch 142/300
# 42500/42500 [==============================] - 19s 447us/step - loss: 0.4082 - accuracy: 0.8565 - val_loss: 0.7909 - val_accuracy: 0.7525
# Epoch 143/300
# 42500/42500 [==============================] - 19s 437us/step - loss: 0.3851 - accuracy: 0.8656 - val_loss: 0.8335 - val_accuracy: 0.7352
# Epoch 144/300
# 42500/42500 [==============================] - 19s 450us/step - loss: 0.4077 - accuracy: 0.8556 - val_loss: 0.8876 - val_accuracy: 0.7232
# Epoch 145/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.4129 - accuracy: 0.8565 - val_loss: 0.8183 - val_accuracy: 0.7408
# Epoch 146/300
# 42500/42500 [==============================] - 19s 436us/step - loss: 0.4000 - accuracy: 0.8597 - val_loss: 0.8505 - val_accuracy: 0.7341
# Epoch 147/300
# 42500/42500 [==============================] - 19s 436us/step - loss: 0.4061 - accuracy: 0.8592 - val_loss: 0.8829 - val_accuracy: 0.7253
# Epoch 148/300
# 42500/42500 [==============================] - 18s 432us/step - loss: 0.4071 - accuracy: 0.8592 - val_loss: 0.8812 - val_accuracy: 0.7160
# Epoch 149/300
# 42500/42500 [==============================] - 19s 449us/step - loss: 0.4005 - accuracy: 0.8606 - val_loss: 0.9301 - val_accuracy: 0.7183
# Epoch 150/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.4177 - accuracy: 0.8529 - val_loss: 0.9801 - val_accuracy: 0.6964
# Epoch 151/300
# 42500/42500 [==============================] - 19s 437us/step - loss: 0.4111 - accuracy: 0.8576 - val_loss: 0.8729 - val_accuracy: 0.7193
# Epoch 152/300
# 42500/42500 [==============================] - 19s 436us/step - loss: 0.4069 - accuracy: 0.8586 - val_loss: 0.9321 - val_accuracy: 0.7093
# Epoch 153/300
# 42500/42500 [==============================] - 19s 438us/step - loss: 0.4237 - accuracy: 0.8524 - val_loss: 0.8082 - val_accuracy: 0.7421
# Epoch 154/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 0.4058 - accuracy: 0.8586 - val_loss: 0.9668 - val_accuracy: 0.6960
# Epoch 155/300
# 42500/42500 [==============================] - 19s 444us/step - loss: 0.4160 - accuracy: 0.8565 - val_loss: 0.8101 - val_accuracy: 0.7437
# Epoch 156/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.4000 - accuracy: 0.8613 - val_loss: 0.8393 - val_accuracy: 0.7352
# Epoch 157/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.3972 - accuracy: 0.8622 - val_loss: 1.0284 - val_accuracy: 0.6944
# Epoch 158/300
# 42500/42500 [==============================] - 19s 438us/step - loss: 0.4098 - accuracy: 0.8570 - val_loss: 0.8794 - val_accuracy: 0.7235
# Epoch 159/300
# 42500/42500 [==============================] - 19s 444us/step - loss: 0.4177 - accuracy: 0.8547 - val_loss: 0.8119 - val_accuracy: 0.7427
# Epoch 160/300
# 42500/42500 [==============================] - 19s 445us/step - loss: 0.3990 - accuracy: 0.8622 - val_loss: 0.8014 - val_accuracy: 0.7415
# Epoch 161/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.3921 - accuracy: 0.8657 - val_loss: 0.9551 - val_accuracy: 0.7029
# Epoch 162/300
# 42500/42500 [==============================] - 18s 435us/step - loss: 0.4165 - accuracy: 0.8540 - val_loss: 0.8699 - val_accuracy: 0.7269
# Epoch 163/300
# 42500/42500 [==============================] - 19s 443us/step - loss: 0.4022 - accuracy: 0.8596 - val_loss: 0.8495 - val_accuracy: 0.7244
# Epoch 164/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.4200 - accuracy: 0.8550 - val_loss: 0.9721 - val_accuracy: 0.6963
# Epoch 165/300
# 42500/42500 [==============================] - 19s 446us/step - loss: 0.4209 - accuracy: 0.8525 - val_loss: 0.8486 - val_accuracy: 0.7283
# Epoch 166/300
# 42500/42500 [==============================] - 19s 437us/step - loss: 0.4099 - accuracy: 0.8565 - val_loss: 0.7897 - val_accuracy: 0.7488
# Epoch 167/300
# 42500/42500 [==============================] - 18s 434us/step - loss: 0.3970 - accuracy: 0.8628 - val_loss: 0.8062 - val_accuracy: 0.7413
# Epoch 168/300
# 42500/42500 [==============================] - 19s 444us/step - loss: 0.3871 - accuracy: 0.8640 - val_loss: 0.9526 - val_accuracy: 0.7077
# Epoch 169/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.4002 - accuracy: 0.8612 - val_loss: 0.8052 - val_accuracy: 0.7437
# Epoch 170/300
# 42500/42500 [==============================] - 19s 445us/step - loss: 0.3797 - accuracy: 0.8673 - val_loss: 0.8454 - val_accuracy: 0.7344
# Epoch 171/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.3887 - accuracy: 0.8640 - val_loss: 0.8216 - val_accuracy: 0.7437
# Epoch 172/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.3735 - accuracy: 0.8694 - val_loss: 0.8109 - val_accuracy: 0.7412
# Epoch 173/300
# 42500/42500 [==============================] - 18s 433us/step - loss: 0.3691 - accuracy: 0.8720 - val_loss: 0.8197 - val_accuracy: 0.7405
# Epoch 174/300
# 42500/42500 [==============================] - 18s 429us/step - loss: 0.3607 - accuracy: 0.8739 - val_loss: 0.8511 - val_accuracy: 0.7333
# Epoch 175/300
# 42500/42500 [==============================] - 18s 434us/step - loss: 0.3613 - accuracy: 0.8747 - val_loss: 0.9741 - val_accuracy: 0.7097
# Epoch 176/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 0.3779 - accuracy: 0.8688 - val_loss: 0.8506 - val_accuracy: 0.7404
# Epoch 177/300
# 42500/42500 [==============================] - 18s 430us/step - loss: 0.3851 - accuracy: 0.8649 - val_loss: 1.0663 - val_accuracy: 0.6864
# Epoch 178/300
# 42500/42500 [==============================] - 19s 444us/step - loss: 0.4050 - accuracy: 0.8584 - val_loss: 0.8323 - val_accuracy: 0.7365
# Epoch 179/300
# 42500/42500 [==============================] - 19s 438us/step - loss: 0.3843 - accuracy: 0.8672 - val_loss: 0.8299 - val_accuracy: 0.7363
# Epoch 180/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 0.3737 - accuracy: 0.8694 - val_loss: 0.8714 - val_accuracy: 0.7299
# Epoch 181/300
# 42500/42500 [==============================] - 19s 440us/step - loss: 0.3789 - accuracy: 0.8668 - val_loss: 0.8232 - val_accuracy: 0.7433
# Epoch 182/300
# 42500/42500 [==============================] - 19s 444us/step - loss: 0.3649 - accuracy: 0.8739 - val_loss: 1.0492 - val_accuracy: 0.6916
# Epoch 183/300
# 42500/42500 [==============================] - 19s 438us/step - loss: 0.3921 - accuracy: 0.8602 - val_loss: 0.7995 - val_accuracy: 0.7441
# Epoch 184/300
# 42500/42500 [==============================] - 19s 438us/step - loss: 0.3652 - accuracy: 0.8746 - val_loss: 0.8540 - val_accuracy: 0.7321
# Epoch 185/300
# 42500/42500 [==============================] - 19s 451us/step - loss: 0.3675 - accuracy: 0.8724 - val_loss: 0.8549 - val_accuracy: 0.7395
# Epoch 186/300
# 42500/42500 [==============================] - 19s 441us/step - loss: 0.3611 - accuracy: 0.8736 - val_loss: 1.1139 - val_accuracy: 0.6889
# Epoch 187/300
# 42500/42500 [==============================] - 19s 442us/step - loss: 0.4150 - accuracy: 0.8551 - val_loss: 0.8052 - val_accuracy: 0.7413
# Epoch 188/300
# 42500/42500 [==============================] - 18s 432us/step - loss: 0.3668 - accuracy: 0.8722 - val_loss: 0.8305 - val_accuracy: 0.7477
# Epoch 189/300
# 42500/42500 [==============================] - 19s 438us/step - loss: 0.3636 - accuracy: 0.8732 - val_loss: 0.9485 - val_accuracy: 0.7191
# Epoch 190/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 0.3855 - accuracy: 0.8671 - val_loss: 0.8243 - val_accuracy: 0.7440
# Epoch 191/300
# 42500/42500 [==============================] - 19s 447us/step - loss: 0.3628 - accuracy: 0.8745 - val_loss: 0.8864 - val_accuracy: 0.7264
# Epoch 192/300
# 42500/42500 [==============================] - 19s 438us/step - loss: 0.3734 - accuracy: 0.8686 - val_loss: 0.8369 - val_accuracy: 0.7427
# Epoch 193/300
# 42500/42500 [==============================] - 19s 439us/step - loss: 0.3699 - accuracy: 0.8712 - val_loss: 0.8760 - val_accuracy: 0.7256
# Epoch 194/300
# 42500/42500 [==============================] - 19s 438us/step - loss: 0.3748 - accuracy: 0.8694 - val_loss: 0.8246 - val_accuracy: 0.7432
# Epoch 195/300
# 42500/42500 [==============================] - 19s 444us/step - loss: 0.3639 - accuracy: 0.8736 - val_loss: 0.9573 - val_accuracy: 0.7109
# Epoch 00195: early stopping
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              8392704
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 39,929,674
# Trainable params: 25,214,986
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
fig1 = plt.figure(figsize = (12,10))
ax1 = fig1.add_subplot(2,2,1)
ax2 = fig1.add_subplot(2,2,2)

ax1.plot(np.arange(1,196), history.val_losses)
ax1.set(xlabel='Epochs', ylabel='Validation Loss',
       title='Epochs vs. Validation Loss')
ax2.plot(np.arange(1,196), history.losses)
ax2.set(xlabel='Epochs', ylabel='Training Loss',
       title='Epochs vs. Training Loss')
plt.show()

# %%
fig1 = plt.figure(figsize = (12,10))
ax1 = fig1.add_subplot(2,2,1)
ax2 = fig1.add_subplot(2,2,2)

ax1.plot(np.arange(1,196), history.val_accuracy)
ax1.set(xlabel='Epochs', ylabel='Validation Accuracy',
       title='Epochs vs. Validation Accuracy')
ax2.plot(np.arange(1,196), history.accuracy)
ax2.set(xlabel='Epochs', ylabel='Training Accuracy',
       title='Epochs vs. Training Accuracy')
plt.show()

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 70.37 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test_prepro[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test_prepro[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [[0]
#  [1]
#  [6]
#  [5]
#  [7]]
# classified as: [8 3 0 3 3]
# True:          [[2]
#  [4]
#  [5]
#  [2]
#  [4]]
# classified as: [3 3 3 3 7]
